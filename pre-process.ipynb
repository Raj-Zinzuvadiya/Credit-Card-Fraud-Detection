# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(f"Total Data Entry: {df.shape[0]}")
# Out:
# Total Data Entry: 284807

# %%
for i in df.columns:
    print(f"Column Name: {i} Column Type: {df[i].dtypes}")
# Out:
# Column Name: Time Column Type: float64
# Column Name: V1 Column Type: float64
# Column Name: V2 Column Type: float64
# Column Name: V3 Column Type: float64
# Column Name: V4 Column Type: float64
# Column Name: V5 Column Type: float64
# Column Name: V6 Column Type: float64
# Column Name: V7 Column Type: float64
# Column Name: V8 Column Type: float64
# Column Name: V9 Column Type: float64
# Column Name: V10 Column Type: float64
# Column Name: V11 Column Type: float64
# Column Name: V12 Column Type: float64
# Column Name: V13 Column Type: float64
# Column Name: V14 Column Type: float64
# Column Name: V15 Column Type: float64
# Column Name: V16 Column Type: float64
# Column Name: V17 Column Type: float64
# Column Name: V18 Column Type: float64
# Column Name: V19 Column Type: float64
# Column Name: V20 Column Type: float64
# Column Name: V21 Column Type: float64
# Column Name: V22 Column Type: float64
# Column Name: V23 Column Type: float64
# Column Name: V24 Column Type: float64
# ...

# %%
# Dropping Time columns
df = df.drop("Time", axis=1)

# %%
X,y = df.iloc[:,:df.shape[1]-1], df["Class"].values

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
print(f"Number of Fraud Record: {df['Class'].value_counts()[1]} \nNumber or Non Fraud Record: {df['Class'].value_counts()[0]}")
# Out:
# Number of Fraud Record: 492
# Number or Non Fraud Record: 284315

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15  9.604066e-16
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01
# max    2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01  3.480167e+01
#
#                  V6            V7            V8            V9           V10  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15  2.239053e-15
# ...

# %%
for i in df.columns:
    print(f"Column Name: {i} Min_Value: {df[i].min()} Max_Value: {df[i].max()}")
# Out:
# Column Name: V1 Min_Value: -56.407509631329 Max_Value: 2.45492999121121
# Column Name: V2 Min_Value: -72.7157275629303 Max_Value: 22.0577289904909
# Column Name: V3 Min_Value: -48.3255893623954 Max_Value: 9.38255843282114
# Column Name: V4 Min_Value: -5.68317119816995 Max_Value: 16.8753440335975
# Column Name: V5 Min_Value: -113.743306711146 Max_Value: 34.8016658766686
# Column Name: V6 Min_Value: -26.1605059358433 Max_Value: 73.3016255459646
# Column Name: V7 Min_Value: -43.5572415712451 Max_Value: 120.589493945238
# Column Name: V8 Min_Value: -73.2167184552674 Max_Value: 20.0072083651213
# Column Name: V9 Min_Value: -13.4340663182301 Max_Value: 15.5949946071278
# Column Name: V10 Min_Value: -24.5882624372475 Max_Value: 23.7451361206545
# Column Name: V11 Min_Value: -4.79747346479757 Max_Value: 12.0189131816199
# Column Name: V12 Min_Value: -18.6837146333443 Max_Value: 7.8483920756446
# Column Name: V13 Min_Value: -5.79188120632084 Max_Value: 7.12688295859376
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df[["V11"]])
plt.plot()
# Out:
# []

# %%
df.corr()
# Out:
#                   V1            V2            V3            V4            V5  \
# V1      1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16  1.812612e-17
# V2      4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15  5.157519e-16
# V3     -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16 -6.539009e-17
# V4     -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00 -1.719944e-15
# V5      1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15  1.000000e+00
# V6     -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16  2.408382e-16
# V7     -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16  2.715541e-16
# V8     -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16  7.437229e-16
# V9     -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16  7.391702e-16
# V10     7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16 -5.202306e-16
# V11     2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16  7.203963e-16
# ...

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ## Saving Scaller

# %%
import joblib
scaler_filename = "scaler.save"
joblib.dump(scaler, scaler_filename) 
# And now to load...

# scaler = joblib.load(scaler_filename)
# Out:
# ['scaler.save']
